# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
from pathlib import Path

# Import API key
from api_keys import geoapify_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="d0e26a1e-e8d1-48b4-b37f-64913a23d7f5" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e9eb4a1b-ab62-486f-9d0c-3ebeb9f6e131":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"ae3b7043b3364e039ead9899853aec7e","client_comm_id":"9f74ce14be52467f94d16d6720385cc7"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"e9eb4a1b-ab62-486f-9d0c-3ebeb9f6e131","roots":{"p1002":"d0e26a1e-e8d1-48b4-b37f-64913a23d7f5"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
csv_file = Path("../output_data/cities.csv")
city_data_df = pd.read_csv(csv_file)

# Display sample data
city_data_df.head()
# Out:
#    City_ID           City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         saipan  15.1355  145.7010     32.39        62          40
# 1        1       afaahiti -17.7500 -149.2833     26.93        80          23
# 2        2     quang ngai  15.1167  108.8000     33.78        50          93
# 3        3  atafu village  -8.5421 -172.5159     29.28        75          79
# 4        4        al jawf  29.5000   38.7500     28.25        15           0
#
#    Wind Speed Country        Date
# 0        5.66      MP  1715319781
# 1        3.39      PF  1715319782
# 2        5.68      VN  1715319743
# 3        2.85      TK  1715319783
# 4        4.96      SA  1715319784

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "CartoLight",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 0.75,
    color = "City"
)
# Display the map
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria
ideal_weather = city_data_df[(city_data_df['Max Temp']>=22) & (city_data_df['Max Temp']<28 ) & (city_data_df['Humidity']>=15)]
ideal_weather
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 1          1         afaahiti -17.7500 -149.2833     26.93        80
# 9          9            mejit  10.2753  170.8646     27.33        84
# 13        13     murwillumbah -28.3167  153.4000     23.32        56
# 23        23        adamstown -25.0660 -130.1015     22.34        82
# 26        26            alofi -19.0595 -169.9187     24.94        73
# ..       ...              ...      ...       ...       ...       ...
# 544      544            kolda  12.8833  -14.9500     25.50        76
# 545      545           nungwi  -5.7265   39.2987     26.06        83
# 549      549       cannonvale -20.2833  148.7000     24.21        76
# 553      553            papao -17.7500 -149.5500     27.82        77
# 555      555  lazaro cardenas  17.9583 -102.2000     22.87        84
#
#      Cloudiness  Wind Speed Country        Date
# 1            23        3.39      PF  1715319782
# 9            98        9.08      MH  1715319788
# 13           40        7.20      AU  1715319791
# 23           94        4.69      PN  1715319798
# 26           75        3.60      NU  1715319800
# ..          ...         ...     ...         ...
# 544          81        2.78      SN  1715320034
# 545          49        7.48      TZ  1715320034
# 549         100        6.98      AU  1715320036
# 553           6        3.77      PF  1715320036
# 555          79        1.09      MX  1715320037
#
# [142 rows x 10 columns]

# %%
# Drop any rows with null values
ideal_weather_wnull = ideal_weather.dropna()

# Display sample data
ideal_weather_wnull
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 1          1         afaahiti -17.7500 -149.2833     26.93        80
# 9          9            mejit  10.2753  170.8646     27.33        84
# 13        13     murwillumbah -28.3167  153.4000     23.32        56
# 23        23        adamstown -25.0660 -130.1015     22.34        82
# 26        26            alofi -19.0595 -169.9187     24.94        73
# ..       ...              ...      ...       ...       ...       ...
# 544      544            kolda  12.8833  -14.9500     25.50        76
# 545      545           nungwi  -5.7265   39.2987     26.06        83
# 549      549       cannonvale -20.2833  148.7000     24.21        76
# 553      553            papao -17.7500 -149.5500     27.82        77
# 555      555  lazaro cardenas  17.9583 -102.2000     22.87        84
#
#      Cloudiness  Wind Speed Country        Date
# 1            23        3.39      PF  1715319782
# 9            98        9.08      MH  1715319788
# 13           40        7.20      AU  1715319791
# 23           94        4.69      PN  1715319798
# 26           75        3.60      NU  1715319800
# ..          ...         ...     ...         ...
# 544          81        2.78      SN  1715320034
# 545          49        7.48      TZ  1715320034
# 549         100        6.98      AU  1715320036
# 553           6        3.77      PF  1715320036
# 555          79        1.09      MX  1715320037
#
# [140 rows x 10 columns]

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_weather_wnull[["City","Country","Lat","Lng","Humidity"]]
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity
# 1           afaahiti      PF -17.7500 -149.2833        80
# 9              mejit      MH  10.2753  170.8646        84
# 13      murwillumbah      AU -28.3167  153.4000        56
# 23         adamstown      PN -25.0660 -130.1015        82
# 26             alofi      NU -19.0595 -169.9187        73
# ..               ...     ...      ...       ...       ...
# 544            kolda      SN  12.8833  -14.9500        76
# 545           nungwi      TZ  -5.7265   39.2987        83
# 549       cannonvale      AU -20.2833  148.7000        76
# 553            papao      PF -17.7500 -149.5500        77
# 555  lazaro cardenas      MX  17.9583 -102.2000        84
#
# [140 rows x 5 columns]

# %%
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"]=''

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 1           afaahiti      PF -17.7500 -149.2833        80
# 9              mejit      MH  10.2753  170.8646        84
# 13      murwillumbah      AU -28.3167  153.4000        56
# 23         adamstown      PN -25.0660 -130.1015        82
# 26             alofi      NU -19.0595 -169.9187        73
# ..               ...     ...      ...       ...       ...        ...
# 544            kolda      SN  12.8833  -14.9500        76
# 545           nungwi      TZ  -5.7265   39.2987        83
# 549       cannonvale      AU -20.2833  148.7000        76
# 553            papao      PF -17.7500 -149.5500        77
# 555  lazaro cardenas      MX  17.9583 -102.2000        84
#
# [140 rows x 6 columns]

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel

radiusMeters = 10000
limit = 1
params = {
    "limit":limit,
    "apiKey":geoapify_key 
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, "Lat"]
    longitude = hotel_df.loc[index, "Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radiusMeters}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    params["categories"] = f"accommodation.hotel"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places?PARAMS"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# afaahiti - nearest hotel: Omati Lodge
# mejit - nearest hotel: No hotel found
# murwillumbah - nearest hotel: Imperial Hotel
# adamstown - nearest hotel: No hotel found
# alofi - nearest hotel: Matavai Resort
# sao vicente - nearest hotel: Pousada Vitória
# remire-montjoly - nearest hotel: Complexe Belova
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# la'ie - nearest hotel: No hotel found
# touros - nearest hotel: Pousada Atlântico
# luanda - nearest hotel: Hotel Forum
# prado - nearest hotel: Pousada Recanto do Prado
# avarua - nearest hotel: Paradise Inn
# port isabel - nearest hotel: Queen Isabel Inn
# cabo san lucas - nearest hotel: Comfort Rooms
# manokwari - nearest hotel: Hotel Arfak
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# todos santos - nearest hotel: Hotel Casa Tota
# hawaiian paradise park - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# west island - nearest hotel: Cocos Village Bungalows
# lai chau - nearest hotel: Minh Tuan Hotel
# campoverde - nearest hotel: No hotel found
# kone - nearest hotel: Pacifik Appartels
# axim - nearest hotel: Axim Beach Hotel
# baiti - nearest hotel: No hotel found
# tambopata - nearest hotel: La Habana
# marsh harbour - nearest hotel: Lofty Fig Villas
# mersa matruh - nearest hotel: صقور
# bonthe - nearest hotel: No hotel found
# soio - nearest hotel: Hotel Maria Teres
# alenquer - nearest hotel: No hotel found
# tanah rata - nearest hotel: Heritage Hotel & Apartment
# puerto baquerizo moreno - nearest hotel: Dory's House
# mount isa - nearest hotel: Ibis Styles
# lihue - nearest hotel: Kauai Palms
# uturoa - nearest hotel: Hawaiki Nui hotel
# alice springs - nearest hotel: Aurora Alice Springs
# tolanaro - nearest hotel: Hôtel Mahavokey
# sao felix do xingu - nearest hotel: Hotel Terraço
# vila velha - nearest hotel: Hotel Prainha
# lodja - nearest hotel: No hotel found
# hafar al-batin - nearest hotel: فندق توليب بلازا
# carutapera - nearest hotel: No hotel found
# iquitos - nearest hotel: Marfil del Amazonas
# ad dilam - nearest hotel: No hotel found
# san julian - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# acarau - nearest hotel: No hotel found
# port-vila - nearest hotel: Holiday Inn Resort Vanuatu
# auki - nearest hotel: No hotel found
# guanica - nearest hotel: Copamarina Beach Resort
# watsa - nearest hotel: No hotel found
# veseloyarsk - nearest hotel: Теремок
# saint-philippe - nearest hotel: Le Baril
# jiangyou - nearest hotel: No hotel found
# antsiranana - nearest hotel: Central
# pitimbu - nearest hotel: Pousada Brisa Mar
# enewetak - nearest hotel: No hotel found
# pucheng - nearest hotel: 浦城县大酒店
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# antonio enes - nearest hotel: Hotel Quirimbas
# nangomba - nearest hotel: No hotel found
# itoman - nearest hotel: No hotel found
# naze - nearest hotel: ビジネス旅館畠山
# hasaki - nearest hotel: Choshi Plaza Hotel
# kete krachi - nearest hotel: Simon Hotel
# boende - nearest hotel: Hotel Reference
# charlotte amalie - nearest hotel: Bunker Hill Hotel
# lorengau - nearest hotel: Seeadler Bay Hotel
# san antonio de pale - nearest hotel: No hotel found
# puerto colombia - nearest hotel: Hotel Puerto Colombia
# paracuru - nearest hotel: Vento Brasil
# hilo - nearest hotel: Dolphin Bay Hotel
# mpulungu - nearest hotel: No hotel found
# cabedelo - nearest hotel: No hotel found
# anori - nearest hotel: NOVO HOTEL
# sena madureira - nearest hotel: No hotel found
# puerto maldonado - nearest hotel: Puerto Palmeras
# sao joao da barra - nearest hotel: Pousada Mediterrâneo
# galveston - nearest hotel: Comfort Inn & Suites Texas City
# kingscliff - nearest hotel: Kingscliff Beach Hotel
# anna regina - nearest hotel: Jaigobin Hotel
# holualoa - nearest hotel: Kona Hotel
# namibe - nearest hotel: Nelsal Pensao
# acapulco de juarez - nearest hotel: Hotel del Valle
# scottburgh - nearest hotel: Blue Marlin Hotel
# porlamar - nearest hotel: Hotel Juan Pescador
# coahuayana de hidalgo - nearest hotel: No hotel found
# witu - nearest hotel: No hotel found
# flying fish cove - nearest hotel: Christmas Island Lodge
# reggane - nearest hotel: No hotel found
# miramar beach - nearest hotel: Embassy Suites by Hilton Destin Miramar Beach
# siwa oasis - nearest hotel: فندق الكيلانى
# port mathurin - nearest hotel: Escale Vacances
# galliano - nearest hotel: Fairfield Inn & Suites by Marriott Cut Off-Galliano
# moree - nearest hotel: No hotel found
# dayr hafir - nearest hotel: No hotel found
# daru - nearest hotel: Kuki
# masina - nearest hotel: Hôtel
# panaba - nearest hotel: No hotel found
# nova vicosa - nearest hotel: Pousada Pontal da Barra
# charters towers - nearest hotel: No hotel found
# guaruja - nearest hotel: Ferrareto Hotel
# burao - nearest hotel: Liiban hotel burco ( ENG:Shibiin )
# san pedro pochutla - nearest hotel: Olimpia
# kirakira - nearest hotel: No hotel found
# cockburn town - nearest hotel: The Salt Raker Inn
# sao paulo de olivenca - nearest hotel: No hotel found
# pointe-noire - nearest hotel: HÔTEL F.A.R.E
# soufriere - nearest hotel: Leisure Inn
# maracacume - nearest hotel: No hotel found
# lamu - nearest hotel: Hotel Archipelago villa bed and breakfast
# guilin - nearest hotel: 丰源酒店
# quixada - nearest hotel: Hotel Monólitos
# inhambane - nearest hotel: Hotel de Inhambane
# bubaque - nearest hotel: Chez Julio
# bahia de caraquez - nearest hotel: No hotel found
# hirara - nearest hotel: 古謝そば屋
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# zouerate - nearest hotel: فندق تيرس زمور
# le port - nearest hotel: No hotel found
# tindouf - nearest hotel: محمد بوسبي
# freetown - nearest hotel: Formal Leona hotel
# fada - nearest hotel: No hotel found
# ambodifotatra - nearest hotel: Les Palmiers
# arecibo - nearest hotel: Arecibo Inn
# benguela - nearest hotel: Hotel Moibela
# plumas lake - nearest hotel: Hard Rock Hotel & Casino Sacramento at Fire Mountain
# timbiqui - nearest hotel: Hotel del Río Guapi
# basoko - nearest hotel: No hotel found
# luganville - nearest hotel: Beachfront Resort
# cuamba - nearest hotel: Pensao Cariaco
# nieuw amsterdam - nearest hotel: Leonsberg Lodge
# santa elena - nearest hotel: Hotel El Gran Jeshua
# kolda - nearest hotel: le firdou
# nungwi - nearest hotel: Mama Fatuma
# cannonvale - nearest hotel: Whitsundays Rainforest Retreat
# papao - nearest hotel: Hiti Moana Villa Lodge
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
#                 City Country      Lat       Lng  Humidity  \
# 1           afaahiti      PF -17.7500 -149.2833        80
# 9              mejit      MH  10.2753  170.8646        84
# 13      murwillumbah      AU -28.3167  153.4000        56
# 23         adamstown      PN -25.0660 -130.1015        82
# 26             alofi      NU -19.0595 -169.9187        73
# ..               ...     ...      ...       ...       ...
# 544            kolda      SN  12.8833  -14.9500        76
# 545           nungwi      TZ  -5.7265   39.2987        83
# 549       cannonvale      AU -20.2833  148.7000        76
# 553            papao      PF -17.7500 -149.5500        77
# 555  lazaro cardenas      MX  17.9583 -102.2000        84
#
#                          Hotel Name
# 1                       Omati Lodge
# 9                    No hotel found
# 13                   Imperial Hotel
# 23                   No hotel found
# 26                   Matavai Resort
# ..                              ...
# 544                       le firdou
# 545                     Mama Fatuma
# 549  Whitsundays Rainforest Retreat
# 553          Hiti Moana Villa Lodge
# 555          Hotel Sol del Pacífico
#
# [140 rows x 6 columns]

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
#Configure the Map Plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "CartoLight",
    frame_width = 700,
    frame_height = 500,
    scale = 1.95,
    color = "City",
    hover_cols= ["Hotel Name","Country"],
    size=10
)
# Display the map
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Hotel Name,Country)
